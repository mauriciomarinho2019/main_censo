# %% [markdown]
# <a href="https://colab.research.google.com/github/mauriciomarinho2019/main_censo/blob/main_censo/Terceiro_notebook_geracao_modelos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Terceiro_notebook_geracao_modelos#
