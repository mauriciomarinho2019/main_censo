# %% [markdown]
# <a href="https://colab.research.google.com/github/mauriciomarinho2019/main_censo/blob/main_censo/Primeiro_notebook_limpeza_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Primeiro Notebook de Limpeza de Dados#
